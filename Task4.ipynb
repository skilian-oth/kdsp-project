# %% [markdown]
# ### Task 4 : Given a twitter user, obtain the tweets and profiles of all followers of the user and show it.

# %% [markdown]
# #### Imports

# %%
# Imports
import pandas as pd # Pandas for dataframes
from IPython.display import display # Display dataframes in Jupyter in conditional statements

# %% [markdown]
# #### Settings

# %%
pd.options.display.max_colwidth = 200 # Increase the size of the output to see the tweet text

# %% [markdown]
# #### Utility functions

# %%
# Return the user id of a user with a given username
def user_id_by_username(username, datasets):

    # Remove the @ symbol, if it exists
    username = username.replace("@", "")

    # Look for the user in the datasets
    for dataset in datasets: # For each dataset

        # Load the authors
        authors_df = pd.read_csv("data/" + dataset + "/authors.csv")

        # Check if the username exists in the dataset using the username column
        author = authors_df[authors_df['username'] == username]

        # If the username exists, return the user id
        if len(author) > 0:
            return author['id'].values[0]
    return None

# %% [markdown]
# #### Main function

# %%
def get_followers_and_their_tweets(user_id, datasets):

        # Try to load the dataframe from the csv file
        try:

            # Load the followers dataframe
            followers_df = pd.read_csv("data/followers/" + str(user_id) + ".csv")
        
        # If the file does not exist, return None
        except FileNotFoundError:
            print('The user in not in the dataset')
            return None, None


        # For each follower, get their tweets in the datasets
        tweets_df = pd.DataFrame()
        for dataset in datasets:
                
                # Load the tweets dataframe
                tweets_df_temp = pd.read_csv("data/" + dataset + "/tweets.csv")
    
                # Filter the tweets to only include the user's followers
                tweets_df_temp = tweets_df_temp[tweets_df_temp['author_id'].isin(followers_df['id'])]

                # Add the name of the author to the tweets dataframe
                for index, row in tweets_df_temp.iterrows():
                    tweets_df_temp.at[index, 'author_name'] = followers_df[followers_df['id'] == row['author_id']]['name'].values[0]
                

                # Add the dataset to the tweets dataframe
                tweets_df = pd.concat([tweets_df, tweets_df_temp])

        # Return the followers dataframe and the tweets dataframe
        return followers_df, tweets_df

# %% [markdown]
# #### Exemple usage

# %%
datasets = ["Paris"]
id = user_id_by_username("@ParisAntan", datasets)


followers_df, tweets_df = get_followers_and_their_tweets(id, datasets)
print("Followers:")
display(followers_df.head())
print("Tweets:")
display(tweets_df[["author_name", "text"]])
# Out:
# Followers:
#                        url        username                created_at  \
# 0                      NaN  romamcallister  2022-06-12T22:43:33.000Z
# 1                      NaN        Sissi785  2020-08-05T11:28:05.000Z
# 2                      NaN   BikeTignolles  2019-03-21T23:18:34.000Z
# 3  https://t.co/3GCUq71RKp    SHAParis8_17  2022-06-11T09:00:41.000Z
# 4                      NaN        tnnblstn  2013-10-20T14:40:39.000Z
#
#                                                                                                                                                         description  \
# 0                                                                                                                      a live moodboard for the ppl who get my vibe
# 1                                                                                                                                                               NaN
# 2                                                                                                                      Les Batignolles -Amboise. Vélociste en herbe
# 3  Fondée en 1898 pour faire connaître l'histoire, les sites, les monuments et les personnages célèbres des 2 arrondissements et défendre leur patrimoine culturel.
# 4                                                                                                                                         Tacere è la nostra virtù.
#
#                                                               profile_image_url  \
# 0  https://pbs.twimg.com/profile_images/1536122850322415617/I3FGPrcg_normal.jpg
# 1  https://pbs.twimg.com/profile_images/1355627462986788873/_54_P0O5_normal.jpg
# 2  https://pbs.twimg.com/profile_images/1108915535373369346/5xKX0iEn_normal.jpg
# 3  https://pbs.twimg.com/profile_images/1535549220895264770/5sMGVCgk_normal.jpg
# 4  https://pbs.twimg.com/profile_images/1395662185859325952/cxOHtPe__normal.jpg
#
#    protected  verified                                                name  \
# 0      False     False                                                dani
# 1       True     False                               Marie le Doucen Perro
# 2      False     False                                       BikeTignolles
# 3      False     False  Société Historique et Archéologique Paris 8e & 17e
# 4      False     False                                            Étienne™
#
#                                                                             public_metrics  \
# 0     {'followers_count': 0, 'following_count': 150, 'tweet_count': 29, 'listed_count': 0}
# 1    {'followers_count': 5, 'following_count': 340, 'tweet_count': 781, 'listed_count': 0}
# 2    {'followers_count': 53, 'following_count': 441, 'tweet_count': 45, 'listed_count': 0}
# 3       {'followers_count': 6, 'following_count': 46, 'tweet_count': 8, 'listed_count': 0}
# 4  {'followers_count': 53, 'following_count': 474, 'tweet_count': 2236, 'listed_count': 0}
#
#                     id                 location  pinned_tweet_id
# 0  1536116954854920192                      NaN              NaN
# 1  1290972481872855040  Côtes-d'Armor, Bretagne              NaN
# 2  1108870543095279616            Paris, France              NaN
# 3  1535547331956842499                    Paris              NaN
# 4           1975358845                    Paris     1.166284e+18
# Tweets:
#                               author_name  \
# 160                   Patrick BERTAUX 🇨🇵😷
# 567   NOTRE-DAME de Paris Cathedral DAILY
# 668                   Patrick BERTAUX 🇨🇵😷
# 1101                       ange gabriel 📷
# 1289                        Paris Chicago
# 1292                        Paris Chicago
# 1293                        Paris Chicago
# 1295                        Paris Chicago
# 1296                        Paris Chicago
# 1297                        Paris Chicago
# 1300                        Paris Chicago
# 1301                        Paris Chicago
# 1302                        Paris Chicago
#
#                                                                                                                                                                                                          text
# 160   📍 Rue Saint-Rustique - #Paris 18éme \n📌 Quartier #Montmartre près de la Place du Tertre \n🚍 #Ligne40_RATP - Place du Tertre-Norvins* \n🚇 Lamarck-Caulaincourt (12) \n* Sous-réserve : il me semble q...
# 567                                                                   Painting by Stanislas Lépine (Public Domain)\n\n#NotreDame #NotreDamedeParis #NotreDameCathedral #Paris #France https://t.co/NcYt6PzIhM
# 668                       📍 Boulevard Pasteur - Boulevard de Vaugirard \n📌 À #Paris 15éme \n🚇 Pasteur (6 &amp; 12) \n🚍 Lignes : 39, 88, 91 &amp; 95 Armorique https://t.co/FmGuUtOPPl https://t.co/4f53R67b1S
# 1101                                                                                                                                                            #Notre_Dame de #Paris https://t.co/s8rTcQbVD8
# 1289                                                                                                                                                                          #Paris🥰 https://t.co/Vc8gUq2DLK
# 1292                                                                                                                                                                          #Paris🥰 https://t.co/kKL49f8kll
# 1293                                                                                                                                                                          #Paris🥰 https://t.co/jkdY1tFPFZ
# 1295                                                                                                                                                                          #Paris🥰 https://t.co/JUo2by8LRZ
# 1296                                                                                                                                                                          #Paris🥰 https://t.co/XSdab9SNxh
# 1297                                                                                                                                                                          #Paris🥰 https://t.co/amphxxJkAl
# 1300                                                                                                                                                                          #Paris🥰 https://t.co/eg9cASPn9G
# 1301                                                                                                                                                                          #Paris🥰 https://t.co/z79QMYVxjM
# 1302                                                                                                                                                                          #Paris🥰 https://t.co/Ue3F9VoZk3
